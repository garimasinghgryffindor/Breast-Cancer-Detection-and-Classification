# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold

import tensorflow as tf

import keras

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers import Lambda, RepeatVector, Reshape
from keras.layers import Conv2D, Conv2DTranspose
from keras.layers import MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import concatenate, add
# from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from tensorflow.keras.utils import img_to_array, img_to_array, load_img
# from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing.image import ImageDataGenerator

# %%
import cv2
import PIL
import plotly.express as px
import seaborn as sns
import glob
import random
import sys

# %%
from os import listdir

# %%
from PIL import Image

# %%
absolute_path = os.path.dirname(os.path.realpath('__file__'))
relative_path = "Kaggel_dataset/csv/mass_case_description_test_set.csv"
full_path = os.path.join(absolute_path, relative_path)
# full_path = "../Kaggel_dataset/mass_case_description_train_set.csv"
csv_mass_test = pd.read_csv(full_path)

# %%
absolute_path = os.path.dirname(os.path.realpath('__file__'))
relative_path = "Kaggel_dataset/csv/mass_case_description_train_set.csv"
full_path = os.path.join(absolute_path, relative_path)
# full_path = "../Kaggel_dataset/mass_case_description_train_set.csv"
csv_mass = pd.read_csv(full_path)

# %%
full_mammo_images_paths_test = csv_mass_test["image file path"]

# %%
full_mammo_images_paths = csv_mass["image file path"]

# %%
roi_images_paths = csv_mass["ROI mask file path"]

# %%
# absolute_path = os.path.dirname(os.path.realpath('__file__'))
# relative_path = "Kaggel_dataset/jpeg"

# image_dir = os.path.join(absolute_path, relative_path)
# image_dir

# %%
absolute_path = os.path.dirname(os.path.realpath('__file__'))
relative_path = "Kaggel_dataset/jpeg"

image_dir = os.path.join(absolute_path, relative_path)
image_dir
# Out:
# '/Users/gryffindorgirl/Desktop/Internship/Kaggel_dataset/jpeg'

# %%
def changeFolderPath(x):
    res = [i for i in range(len(x)) if x.startswith("/", i)]
    idx = res[1]
    folderPath = x[0:idx]
    x = x.replace(folderPath, image_dir)
    return x

# %%
full_mammo_images_paths_test = full_mammo_images_paths_test.apply(changeFolderPath)
full_mammo_images_paths_test.head()
# Out:
# 0    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 1    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 2    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 3    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 4    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# Name: image file path, dtype: object

# %%
full_mammo_images_paths = full_mammo_images_paths.apply(changeFolderPath)
full_mammo_images_paths.head()
# Out:
# 0    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 1    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 2    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 3    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 4    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# Name: image file path, dtype: object

# %%
roi_images_paths = roi_images_paths.apply(changeFolderPath)
roi_images_paths.head()
# Out:
# 0    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 1    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 2    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 3    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 4    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# Name: ROI mask file path, dtype: object

# %%
def changeFilePath(x):
    res = [i for i in range(len(x)) if x.startswith("/", i)]
    idx_start = res[7]+1
    fileName = x[idx_start:]
    x = x.replace(fileName, 'full__pre__res.jpg')
    return x

# %%
def changeFilePath2(x):
    res = [i for i in range(len(x)) if x.startswith("/", i)]
    idx_start = res[7]+1
    fileName = x[idx_start:]
    x = x.replace(fileName, 'roi__pre__res.jpg')
    return x

# %%
full_mammo_images_paths_test = full_mammo_images_paths_test.apply(changeFilePath)
full_mammo_images_paths_test.head()
# Out:
# 0    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 1    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 2    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 3    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 4    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# Name: image file path, dtype: object

# %%
full_mammo_images_paths = full_mammo_images_paths.apply(changeFilePath)
full_mammo_images_paths.head()
# Out:
# 0    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 1    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 2    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 3    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 4    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# Name: image file path, dtype: object

# %%
roi_images_paths = roi_images_paths.apply(changeFilePath2)
roi_images_paths.head()
# Out:
# 0    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 1    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 2    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 3    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# 4    /Users/gryffindorgirl/Desktop/Internship/Kagge...
# Name: ROI mask file path, dtype: object

# %%
def read_images_from_paths(file_paths):
    images = []
    for path in file_paths:
        try:
            img = Image.open(path)
            images.append(np.array(img))  # Convert the image to a numpy array and append to the list
        except Exception as e:
            print(f"Error loading image from '{path}': {e}")
    return images

# %%
array_of_images_test = read_images_from_paths(full_mammo_images_paths_test)

# %%
array_of_images = read_images_from_paths(full_mammo_images_paths)

# %%
len(array_of_images)
# Out:
# 1318

# %%
plt.imshow(array_of_images[0], cmap='gray')

# %%
array_of_roi = read_images_from_paths(roi_images_paths)

# %%
array_of_roi[0].shape
# Out:
# (256, 256)

# %%
len(array_of_roi)
# Out:
# 1318

# %%
# Set some parameters
im_width = 256
im_height = 256
border = 5

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
def compute_iou(y_true, y_pred):
    
    intersection = (y_true * y_pred).sum()
    union = y_true.sum() + y_pred.sum() - intersection
    x = (intersection + 1e-15) / (union + 1e-15)
    x = x.astype(np.float32)
    
    return x

# %%
input_img = Input((im_height, im_width, 1), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# Metal device set to: Apple M1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  img (InputLayer)            [(None, 256, 256, 1)]        0         []
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         160       ['img[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 16)         64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 16)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['activation_1[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 128, 128, 16)         0         ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         4640      ['dropout[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 32)         128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)           0         ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           18496     ['dropout_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_5[0][0]']
#  g2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)           0         ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          73856     ['dropout_2[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_7[0][0]']
#  g2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)          0         ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          295168    ['dropout_3[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          295040    ['activation_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'activation_7[0][0]']
#
#  dropout_4 (Dropout)         (None, 32, 32, 256)          0         ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)          295040    ['dropout_4[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           73792     ['activation_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  dropout_5 (Dropout)         (None, 64, 64, 128)          0         ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 64)           73792     ['dropout_5[0][0]']
#
#  batch_normalization_13 (Ba  (None, 64, 64, 64)           256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 32)         18464     ['activation_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 32)         18464     ['dropout_6[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 32)         128       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 16)         4624      ['activation_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 16)         4624      ['dropout_7[0][0]']
#
#  batch_normalization_17 (Ba  (None, 256, 256, 16)         64        ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 1)          17        ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 1179121 (4.50 MB)
# Trainable params: 1177649 (4.49 MB)
# Non-trainable params: 1472 (5.75 KB)
# __________________________________________________________________________________________________

# %%
pip install pydot
# Out:
# Requirement already satisfied: pydot in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow2/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow2/lib/python3.10/site-packages (from pydot) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow2/lib/python3.10/site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
input_img = Input((im_height, im_width, 1), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  img (InputLayer)            [(None, 256, 256, 1)]        0         []
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 16)         160       ['img[0][0]']
#
#  batch_normalization_19 (Ba  (None, 256, 256, 16)         64        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 128, 128, 16)         0         ['activation_19[0][0]']
#  g2D)
#
#  dropout_8 (Dropout)         (None, 128, 128, 16)         0         ['max_pooling2d_4[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 32)         4640      ['dropout_8[0][0]']
#
#  batch_normalization_21 (Ba  (None, 128, 128, 32)         128       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_21[0][0]']
#  g2D)
#
#  dropout_9 (Dropout)         (None, 64, 64, 32)           0         ['max_pooling2d_5[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 64)           18496     ['dropout_9[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 64)           256       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_23[0][0]']
#  g2D)
#
#  dropout_10 (Dropout)        (None, 32, 32, 64)           0         ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 128)          73856     ['dropout_10[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_25[0][0]']
#  g2D)
#
#  dropout_11 (Dropout)        (None, 16, 16, 128)          0         ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 256)          295168    ['dropout_11[0][0]']
#
#  batch_normalization_27 (Ba  (None, 16, 16, 256)          1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_transpose_4 (Conv2D  (None, 32, 32, 128)          295040    ['activation_27[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 32, 32, 256)          0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'activation_25[0][0]']
#
#  dropout_12 (Dropout)        (None, 32, 32, 256)          0         ['concatenate_4[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 128)          295040    ['dropout_12[0][0]']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 128)          512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_transpose_5 (Conv2D  (None, 64, 64, 64)           73792     ['activation_29[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'activation_23[0][0]']
#
#  dropout_13 (Dropout)        (None, 64, 64, 128)          0         ['concatenate_5[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 64)           73792     ['dropout_13[0][0]']
#
#  batch_normalization_31 (Ba  (None, 64, 64, 64)           256       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_transpose_6 (Conv2D  (None, 128, 128, 32)         18464     ['activation_31[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'activation_21[0][0]']
#
#  dropout_14 (Dropout)        (None, 128, 128, 64)         0         ['concatenate_6[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 128, 128, 32)         18464     ['dropout_14[0][0]']
#
#  batch_normalization_33 (Ba  (None, 128, 128, 32)         128       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_transpose_7 (Conv2D  (None, 256, 256, 16)         4624      ['activation_33[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  dropout_15 (Dropout)        (None, 256, 256, 32)         0         ['concatenate_7[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 256, 256, 16)         4624      ['dropout_15[0][0]']
#
#  batch_normalization_35 (Ba  (None, 256, 256, 16)         64        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 256, 256, 1)          17        ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 1179121 (4.50 MB)
# Trainable params: 1177649 (4.49 MB)
# Non-trainable params: 1472 (5.75 KB)
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 train_labels = tf.keras.utils.to_categorical(train_labels)
#       2 test_labels = tf.keras.utils.to_categorical(test_labels)
#
# NameError: name 'train_labels' is not defined

# %%
X_train, X_valid, y_train, y_valid = train_test_split(array_of_images, array_of_roi, test_size=0.1, random_state=42)

# %%
len(X_valid)
# Out:
# 132

# %%
len(y_train)
# Out:
# 1186

# %%
len(X_train)
# Out:
# 1186

# %%
X_train[0]
# Out:
# array([[177, 178, 164, ...,   0,   0,   0],
#        [185, 181, 158, ...,   0,   0,   0],
#        [184, 174, 155, ...,   0,   0,   0],
#        ...,
#        [100,  55,  34, ...,   0,   0,   0],
#        [100,  53,  26, ...,   0,   0,   0],
#        [101,  64,  39, ...,   0,   0,   0]], dtype=uint8)

# %%
arr = np.array(X_train)

# %%
X_train[0]
# Out:
# array([[177, 178, 164, ...,   0,   0,   0],
#        [185, 181, 158, ...,   0,   0,   0],
#        [184, 174, 155, ...,   0,   0,   0],
#        ...,
#        [100,  55,  34, ...,   0,   0,   0],
#        [100,  53,  26, ...,   0,   0,   0],
#        [101,  64,  39, ...,   0,   0,   0]], dtype=uint8)

# %%
arr[0]
# Out:
# array([[177, 178, 164, ...,   0,   0,   0],
#        [185, 181, 158, ...,   0,   0,   0],
#        [184, 174, 155, ...,   0,   0,   0],
#        ...,
#        [100,  55,  34, ...,   0,   0,   0],
#        [100,  53,  26, ...,   0,   0,   0],
#        [101,  64,  39, ...,   0,   0,   0]], dtype=uint8)

# %%
tf.config.run_functions_eagerly(True)

# %%
X = np.zeros((3*len(array_of_images), im_height, im_width, 1), dtype=np.float32)
y = np.zeros((3*len(array_of_roi), im_height, im_width, 1), dtype=np.float32)

# %%
def imgAugment(x_img, y_img):

    # =========
    #  LR Flip
    # =========
    # Generate random number from uniform distribution
    # in the range [0.0, 1.0)
    if tf.random.uniform(()) > 0.5:
        x_img = tf.image.flip_left_right(image=x_img)
        y_img = tf.image.flip_left_right(image=y_img)

    # =========
    #  UD Flip
    # =========
    if tf.random.uniform(()) > 0.5:
        x_img = tf.image.flip_up_down(image=x_img)
        y_img = tf.image.flip_up_down(image=y_img)

    # ============
    #  Brightness
    # ============
    # Only change the brightness of x_img, not y_img!
    delta = np.random.uniform(-50, 50)
    augmented_image = x_img + delta
    x_img = np.clip(augmented_image, 0, 255).astype(np.uint8)
    
#     x_img = tf.image.random_brightness(
#         image=x_img, max_delta=self.brightness_delta
#     )

    return x_img, y_img

# %%
for i in range(len(array_of_images)):
    # Load images
#     img = load_img("images/"+id_, grayscale=True)
#     x_img = img_to_array(img)
#     x_img = resize(x_img, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Load masks
#     mask = img_to_array(load_img("masks/"+id_, grayscale=True))
#     mask = resize(mask, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Save images
    img1, roi1 = imgAugment(array_of_images[i], array_of_roi[i])
    img2, roi2 = imgAugment(array_of_images[i], array_of_roi[i])
    img3, roi3 = imgAugment(array_of_images[i], array_of_roi[i])
    
    x_img1 = resize(img1, (256, 256, 1), mode='constant', preserve_range=True)
    y_img1 = resize(roi1, (256, 256, 1), mode='constant', preserve_range=True)
    x_img2 = resize(img2, (256, 256, 1), mode='constant', preserve_range=True)
    y_img2 = resize(roi2, (256, 256, 1), mode='constant', preserve_range=True)
    x_img3 = resize(img3, (256, 256, 1), mode='constant', preserve_range=True)
    y_img3 = resize(roi3, (256, 256, 1), mode='constant', preserve_range=True)
    
    X[3*i+0] = (x_img1)/255.0
    y[3*i+0] = (y_img1)/255.0
    X[3*i+1] = (x_img2)/255.0
    y[3*i+1] = (y_img2)/255.0
    X[3*i+2] = (x_img3)/255.0
    y[3*i+2] = (y_img3)/255.0

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
results = model.fit(X_train, y_train, batch_size=32, epochs=50, callbacks=callbacks,\
                    validation_data=(X_valid, y_valid))
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow2/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# Epoch 1/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9946
# Epoch 1: val_loss improved from 0.01441 to 0.01434, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 110s 972ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.0143 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 2/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9947
# Epoch 2: val_loss improved from 0.01434 to 0.01411, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 951ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 0.0141 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 3/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9947
# Epoch 3: val_loss improved from 0.01411 to 0.01402, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 532s 5s/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 0.0140 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 4/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9947
# Epoch 4: val_loss improved from 0.01402 to 0.01391, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 953s 9s/step - loss: 0.0141 - accuracy: 0.9947 - val_loss: 0.0139 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 5/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9947
# Epoch 5: val_loss did not improve from 0.01391
# 112/112 [==============================] - 107s 954ms/step - loss: 0.0140 - accuracy: 0.9947 - val_loss: 0.0139 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 6/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9948
# Epoch 6: val_loss improved from 0.01391 to 0.01380, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 953ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0138 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 7/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9947
# Epoch 7: val_loss improved from 0.01380 to 0.01374, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 955ms/step - loss: 0.0139 - accuracy: 0.9947 - val_loss: 0.0137 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 8/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9948
# Epoch 8: val_loss improved from 0.01374 to 0.01370, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 108s 964ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0137 - val_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 9/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9948
# Epoch 9: val_loss improved from 0.01370 to 0.01365, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 110s 982ms/step - loss: 0.0138 - accuracy: 0.9948 - val_loss: 0.0136 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 10/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9948
# Epoch 10: val_loss improved from 0.01365 to 0.01363, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 125s 1s/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 0.0136 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 11/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9948
# Epoch 11: val_loss improved from 0.01363 to 0.01354, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 127s 1s/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 0.0135 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 12/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9948
# Epoch 12: val_loss did not improve from 0.01354
# 112/112 [==============================] - 132s 1s/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 0.0135 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 13/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9947
# Epoch 13: val_loss improved from 0.01354 to 0.01354, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 141s 1s/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 0.0135 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 14/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9948
# Epoch 14: val_loss improved from 0.01354 to 0.01341, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 1759s 16s/step - loss: 0.0135 - accuracy: 0.9948 - val_loss: 0.0134 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 15/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9948
# Epoch 15: val_loss improved from 0.01341 to 0.01337, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 956ms/step - loss: 0.0135 - accuracy: 0.9948 - val_loss: 0.0134 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 16/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9948
# Epoch 16: val_loss improved from 0.01337 to 0.01334, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 953ms/step - loss: 0.0135 - accuracy: 0.9948 - val_loss: 0.0133 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 17/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9948
# Epoch 17: val_loss improved from 0.01334 to 0.01323, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 216s 2s/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.0132 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 18/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9948
# Epoch 18: val_loss improved from 0.01323 to 0.01320, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 953ms/step - loss: 0.0135 - accuracy: 0.9948 - val_loss: 0.0132 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 19/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9948
# Epoch 19: val_loss improved from 0.01320 to 0.01318, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 958ms/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.0132 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 20/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9948
# Epoch 20: val_loss improved from 0.01318 to 0.01315, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 113s 1s/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.0131 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 21/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9948
# Epoch 21: val_loss improved from 0.01315 to 0.01309, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 293s 3s/step - loss: 0.0133 - accuracy: 0.9948 - val_loss: 0.0131 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 22/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9948
# Epoch 22: val_loss did not improve from 0.01309
# 112/112 [==============================] - 107s 955ms/step - loss: 0.0132 - accuracy: 0.9948 - val_loss: 0.0131 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 23/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9948
# Epoch 23: val_loss improved from 0.01309 to 0.01298, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 123s 1s/step - loss: 0.0132 - accuracy: 0.9948 - val_loss: 0.0130 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 24/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9948
# Epoch 24: val_loss did not improve from 0.01298
# 112/112 [==============================] - 133s 1s/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 0.0130 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 25/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9948
# Epoch 25: val_loss improved from 0.01298 to 0.01291, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 141s 1s/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 0.0129 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 26/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9948
# Epoch 26: val_loss improved from 0.01291 to 0.01284, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 151s 1s/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 0.0128 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 27/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9948
# Epoch 27: val_loss improved from 0.01284 to 0.01280, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 152s 1s/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 0.0128 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 28/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9948
# Epoch 28: val_loss improved from 0.01280 to 0.01280, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 225s 2s/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 0.0128 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 29/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9948
# Epoch 29: val_loss improved from 0.01280 to 0.01269, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 108s 962ms/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 0.0127 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 30/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9948
# Epoch 30: val_loss improved from 0.01269 to 0.01265, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 123s 1s/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 0.0127 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 31/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9948
# Epoch 31: val_loss improved from 0.01265 to 0.01258, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 539s 5s/step - loss: 0.0128 - accuracy: 0.9948 - val_loss: 0.0126 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 32/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9948
# Epoch 32: val_loss improved from 0.01258 to 0.01250, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 108s 966ms/step - loss: 0.0127 - accuracy: 0.9948 - val_loss: 0.0125 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 33/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9948
# Epoch 33: val_loss improved from 0.01250 to 0.01248, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 108s 968ms/step - loss: 0.0127 - accuracy: 0.9948 - val_loss: 0.0125 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 34/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9948
# Epoch 34: val_loss improved from 0.01248 to 0.01242, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 123s 1s/step - loss: 0.0127 - accuracy: 0.9948 - val_loss: 0.0124 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 35/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9948
# Epoch 35: val_loss improved from 0.01242 to 0.01235, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 127s 1s/step - loss: 0.0126 - accuracy: 0.9948 - val_loss: 0.0123 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 36/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9948
# Epoch 36: val_loss did not improve from 0.01235
# 112/112 [==============================] - 252s 2s/step - loss: 0.0126 - accuracy: 0.9948 - val_loss: 0.0124 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 37/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9948
# Epoch 37: val_loss improved from 0.01235 to 0.01232, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 106s 946ms/step - loss: 0.0125 - accuracy: 0.9948 - val_loss: 0.0123 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 38/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9948
# Epoch 38: val_loss improved from 0.01232 to 0.01230, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 113s 1s/step - loss: 0.0124 - accuracy: 0.9948 - val_loss: 0.0123 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 39/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9948
# Epoch 39: val_loss improved from 0.01230 to 0.01226, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 123s 1s/step - loss: 0.0124 - accuracy: 0.9948 - val_loss: 0.0123 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 40/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9949
# Epoch 40: val_loss improved from 0.01226 to 0.01220, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 125s 1s/step - loss: 0.0124 - accuracy: 0.9949 - val_loss: 0.0122 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 41/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9949
# Epoch 41: val_loss improved from 0.01220 to 0.01209, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 266s 2s/step - loss: 0.0123 - accuracy: 0.9949 - val_loss: 0.0121 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 42/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9948
# Epoch 42: val_loss improved from 0.01209 to 0.01207, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 107s 953ms/step - loss: 0.0123 - accuracy: 0.9948 - val_loss: 0.0121 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 43/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9949
# Epoch 43: val_loss improved from 0.01207 to 0.01197, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 148s 1s/step - loss: 0.0122 - accuracy: 0.9949 - val_loss: 0.0120 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 44/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9949
# Epoch 44: val_loss improved from 0.01197 to 0.01195, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 180s 2s/step - loss: 0.0122 - accuracy: 0.9949 - val_loss: 0.0119 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 45/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9949
# Epoch 45: val_loss improved from 0.01195 to 0.01192, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 207s 2s/step - loss: 0.0121 - accuracy: 0.9949 - val_loss: 0.0119 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 46/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9949
# Epoch 46: val_loss improved from 0.01192 to 0.01191, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 248s 2s/step - loss: 0.0120 - accuracy: 0.9949 - val_loss: 0.0119 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 47/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9949
# Epoch 47: val_loss improved from 0.01191 to 0.01177, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 277s 2s/step - loss: 0.0120 - accuracy: 0.9949 - val_loss: 0.0118 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 48/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9949
# Epoch 48: val_loss improved from 0.01177 to 0.01172, saving model to model-tgs-salt.h5
# 112/112 [==============================] - 280s 3s/step - loss: 0.0119 - accuracy: 0.9949 - val_loss: 0.0117 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 49/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9949
# Epoch 49: val_loss did not improve from 0.01172
# 112/112 [==============================] - 286s 3s/step - loss: 0.0119 - accuracy: 0.9949 - val_loss: 0.0119 - val_accuracy: 0.9949 - lr: 1.0000e-05
# Epoch 50/50
# 112/112 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9949
# Epoch 50: val_loss did not improve from 0.01172
# 112/112 [==============================] - 200s 2s/step - loss: 0.0119 - accuracy: 0.9949 - val_loss: 0.0117 - val_accuracy: 0.9949 - lr: 1.0000e-05

# %%
# GenerateInputs(X=x_train, y=y_train)

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
model.load_weights('model-tgs-salt.h5')

# %%
# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0118 - accuracy: 0.9950
# [0.011842208914458752, 0.9949553608894348]

# %%
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 112/112 [==============================] - 26s 235ms/step
# 13/13 [==============================] - 3s 220ms/step

# %%
X_validate = np.zeros((len(array_of_images_test), im_height, im_width, 1), dtype=np.float32)
# y_validate = np.zeros((len(array_of_roi), im_height, im_width, 1), dtype=np.float32)

# %%
for i in range(len(array_of_images_test)):
    x_img = resize(array_of_images[i], (256, 256, 1), mode='constant', preserve_range=True)
    X_validate[i] = (x_img)/255.0

# %%
preds_validate = model.predict(X_validate, verbose=1)
# Out:
# 12/12 [==============================] - 2s 221ms/step

# %%
len(preds_validate)
# Out:
# 378

# %%
full_mammo_images_paths_test[0]
# Out:
# '/Users/gryffindorgirl/Desktop/Internship/Kaggel_dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.245063149211255120613007755642780114172/full__pre__res.jpg'

# %%
plt.imshow(array_of_images[898], cmap='gray')

# %%
plt.imshow(X_validate[100], cmap='gray')

# %%
plt.imshow(preds_validate[100], cmap='gray')

# %%
plt.imshow(preds_train[1900], cmap='gray')

# %%
# preds_train = model.predict(X_train, verbose=1)
# preds_val = model.predict(X_valid, verbose=1)

# %%
# model = unetVgg16.unetVgg16()
# unet = model.buildUnet(dropout_training=False)
# unet = model.compile_(model=unet)

# # Load pre-trained weights from desired checkpoint file.
# latest = tf.train.latest_checkpoint('model-tgs-salt.h5')
# print(latest)
# unet.load_weights(filepath=latest)

# # =========
# #  Predict
# # =========
# predicted_outputs = unet.predict(x=test_imgs, batch_size=len(test_imgs))

# %%
# input_img = Input((im_height, im_width, 1), name='img')
# unet = get_unet(dropout_training=False)
# unet.compile(model=unet)

# latest = tf.train.latest_checkpoint('model-tgs-salt.h5')
# print(latest)
# unet.load_weights(filepath=latest)

# predicted_outputs = unet.predict(x=array_of_images_test[0], batch_size=len(array_of_images_test[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 input_img = Input((im_height, im_width, 1), name='img')
# ----> 2 unet = get_unet(dropout_training=False)
#       3 unet.compile(model=unet)
#       5 latest = tf.train.latest_checkpoint('model-tgs-salt.h5')
#
# TypeError: get_unet() got an unexpected keyword argument 'dropout_training'

# %%
plt.imshow(array_of_images_test[0], cmap='gray')

# %%
# m1 = tf.keras.models.load_model('model-tgs-salt.h5')

# %%
# k = 5  # Number of folds
# kf = KFold(n_splits=k, shuffle=True, random_state=42)

# for fold, (train_index, val_index) in enumerate(kf.split(array_of_images)):
#     print(f"Training on Fold {fold + 1}")

#     # Create the U-Net model
# #     model = create_unet_model(input_shape=(height, width, num_channels), num_classes=num_classes)
#     input_img = Input((im_height, im_width, 1), name='img')
#     model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)

#     # Compile the model with IoU as a metric and an appropriate loss and optimizer
# #     model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', iou_score])
# #     keras.utils.plot_model(model, to_file="./experimental_outputs/unet_model_v1.png", show_shapes=True,show_layer_names=True, dpi=300)
#     model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])

#     # Split the data into training and validation sets for this fold
#     x_train, x_val = array_of_images[train_index], array_of_images[val_index]
#     y_train, y_val = array_of_roi[train_index], array_of_roi[val_index]

#     # Define the early stopping callback
#     callbacks = [
#     EarlyStopping(patience=10, verbose=1),
#     ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
#     ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
#     ]
# #     early_stopping = EarlyStopping(monitor='val_iou_score', patience=3, mode='max', restore_best_weights=True)

#     # Train the model for this fold with early stopping
#     results = model.fit(x_train, y_train, batch_size=32, epochs=50, callbacks=callbacks,validation_data=(x_val, y_val))
# #     model.fit(x_train, y_train, batch_size=32, epochs=100,
# #               validation_data=(x_val, y_val), callbacks=[early_stopping])

#     # Evaluate the model on the test set or save the model weights for later use
#     # (This step is typically done outside the k-fold loop)
# Out:
# Training on Fold 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 18
#      15 model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
#      17 # Split the data into training and validation sets for this fold
# ---> 18 x_train, x_val = array_of_images[train_index], array_of_images[val_index]
#      19 y_train, y_val = array_of_roi[train_index], array_of_roi[val_index]
#      21 # Define the early stopping callback
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
# plt.figure(figsize=(8, 8))
# plt.title("Learning curve")
# plt.plot(results.history["loss"], label="loss")
# plt.plot(results.history["val_loss"], label="val_loss")
# plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
# plt.xlabel("Epochs")
# plt.ylabel("log_loss")
# plt.legend();

# %%
# model.load_weights('model-tgs-salt.h5')

# %%
# model.evaluate(X_valid, y_valid, verbose=1)
